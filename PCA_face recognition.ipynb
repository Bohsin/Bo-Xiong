# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.datasets import fetch_lfw_people

# %%
faces = fetch_lfw_people(min_faces_per_person=60)

# %%
 faces.keys()
# Out:
# dict_keys(['data', 'images', 'target', 'target_names', 'DESCR'])

# %%
faces.data.shape
# Out:
# (1348, 2914)

# %%
faces.images.shape[1:]
# Out:
# (62, 47)

# %%
fig, axes = plt.subplots(4,5
                         ,figsize=(6,5)
                         ,subplot_kw={"xticks":[],"yticks":[]}
                        )
for i, axe in enumerate(axes.ravel()):
    axe.imshow(faces.images[i,:,:],cmap='gray')

# %%
pca = PCA(n_components=150)
pca.fit(faces.data)
x_dr = pca.transform(faces.data)

# %%
x_dr.shape
# Out:
# (1348, 150)

# %%
x_it = x_dr.dot(v)

# %%
x_it.shape
# Out:
# (1348, 2914)

# %%
x_it2 = pca.inverse_transform(x_dr)

# %%
x_it2.shape
# Out:
# (1348, 2914)

# %%
v = pca.components_

# %%
v.shape
# Out:
# (150, 2914)

# %%
fig, axes = plt.subplots(4,5
                         ,figsize=(6,5)
                         ,subplot_kw={"xticks":[],"yticks":[]}
                        )
for i, axe in enumerate(axes.ravel()):
    axe.imshow(v[i,:].reshape(faces.images.shape[1:]),cmap='gray')

# %%
fig, axes = plt.subplots(4,5
                         ,figsize=(6,5)
                         ,subplot_kw={"xticks":[],"yticks":[]}
                        )
for i, axe in enumerate(axes.ravel()):
    axe.imshow(x_it[i,:].reshape(faces.images.shape[1:]),cmap='gray')

# %%
fig, axes = plt.subplots(4,5
                         ,figsize=(6,5)
                         ,subplot_kw={"xticks":[],"yticks":[]}
                        )
for i, axe in enumerate(axes.ravel()):
    axe.imshow(x_it2[i,:].reshape(faces.images.shape[1:]),cmap='gray')
